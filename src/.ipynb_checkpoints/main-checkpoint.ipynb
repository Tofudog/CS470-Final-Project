# %% [markdown]
# ## Import the Required Data and Libraries

# %%
# %pip install matplotlib
# %pip install pandas
# %pip install numpy
# Out:
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/סביבה–לאונרדו/lib/python3.11/site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/סביבה–לאונרדו/lib/python3.11/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/סביבה–לאונרדו/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/סביבה–לאונרדו/lib/python3.11/site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/סביבה–לאונרדו/lib/python3.11/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /opt/anaconda3/envs/סביבה–לאונרדו/lib/python3.11/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/סביבה–לאונרדו/lib/python3.11/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/סביבה–לאונרדו/lib/python3.11/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/סביבה–לאונרדו/lib/python3.11/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/סביבה–לאונרדו/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/סביבה–לאונרדו/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /opt/anaconda3/envs/סביבה–לאונרדו/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in /opt/anaconda3/envs/סביבה–לאונרדו/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/סביבה–לאונרדו/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/סביבה–לאונרדו/lib/python3.11/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/סביבה–לאונרדו/lib/python3.11/site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/סביבה–לאונרדו/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /opt/anaconda3/envs/סביבה–לאונרדו/lib/python3.11/site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
import os

# %%
DATA_DIRECTORY = "../data/"
RAW_DATA_FILE = f"{DATA_DIRECTORY}/database_raw.csv"

assert os.path.isdir(DATA_DIRECTORY)
assert os.path.isfile(RAW_DATA_FILE)

# %% [raw]
# Preprocess:
# -Remove non-natural quakes
# -Remove columns with many missing values or irrelevant information
# -Remove unreadable dates/times

# %%
raw_df = pd.read_csv(RAW_DATA_FILE)

df = raw_df.copy()

df = df[df["Type"] != "Nuclear Explosion"]
df = df[df["Type"] != "Rock Burst"]
df = df[df["Type"] != "Explosion"]

df = df.drop(['Depth Error','Depth Seismic Stations','Magnitude Error', 'Magnitude Seismic Stations','Azimuthal Gap', 'Horizontal Distance', 'Horizontal Error', 'Root Mean Square', 'Location Source', 'Magnitude Source', 'Status', 'ID', 'Source', 'Type'], axis=1)

df = df[not df["Date"].endswith("Z")]
df = df[not df["Time"].endswith("Z")]

DATA_FILE = f"{DATA_DIRECTORY}/earthquakes.csv"
if not os.path.isfile(DATA_FILE): df.to_csv(DATA_FILE, index=False)

# %%
df.head()
# Out:
#          Date      Time  Latitude  Longitude  Depth  Magnitude Magnitude Type
# 0  01/02/1965  13:44:18    19.246    145.616  131.6        6.0             MW
# 1  01/04/1965  11:29:49     1.863    127.352   80.0        5.8             MW
# 2  01/05/1965  18:05:58   -20.579   -173.972   20.0        6.2             MW
# 3  01/08/1965  18:49:43   -59.076    -23.557   15.0        5.8             MW
# 4  01/09/1965  13:32:50    11.938    126.427   15.0        5.8             MW
